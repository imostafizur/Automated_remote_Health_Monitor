# %% [markdown]
# ### ECG csv dataset heartbeat abnormality detection

# %%
# Import library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# #### Normal heart beat

# %%
# Load csv dataset
df = pd.read_csv('ptbdb_normal.csv')

# %%
# dataset details
print(df.shape)
# Out:
# (4045, 188)

# %%
# dataset info
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4045 entries, 0 to 4044
# Columns: 188 entries, 1.000000000000000000e+00 to 0.000000000000000000e+00.65
# dtypes: float64(188)
# memory usage: 5.8 MB
# None

# %%
# Abnoraml hearbeat csv load
df_abnormal = pd.read_csv('ptbdb_abnormal.csv')

# %%
# Join two dataset and label to normal and abnormal
df = pd.concat([df, df_abnormal], axis=0)

# %%
df.head()
# Out:
#    1.000000000000000000e+00  9.003241658210754395e-01  \
# 0                  1.000000                  0.794681
# 1                  0.909029                  0.791482
# 2                  1.000000                  0.478893
# 3                  1.000000                  0.867238
# 4                  0.948983                  0.505265
#
#    3.585899472236633301e-01  5.145867168903350830e-02  \
# 0                  0.375387                  0.116883
# 1                  0.423169                  0.186712
# 2                  0.056760                  0.064176
# 3                  0.201360                  0.099349
# 4                  0.004176                  0.022513
#
#    4.659643396735191345e-02  1.268233358860015869e-01  \
# 0                  0.000000                  0.171923
# 1                  0.000000                  0.007836
# 2                  0.081289                  0.072732
# 3                  0.141336                  0.120934
# ...

# %%
# number of features
print(df.shape)
# Out:
# (14550, 309)

# %%
# Ecg signal plot
plt.figure(figsize=(50, 5))
plt.plot(df.iloc[0, :])
plt.title('ECG Signal')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.show()

# %%
# ECG signal plot using seaborn
plt.figure(figsize=(20, 5))
sns.lineplot(data=df.iloc[0, :])
plt.title('ECG Signal')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.show()

# %%
# dataset split df and df_abnormal
df_normal = df.iloc[:4046, :]
df_abnormal = df.iloc[4046:, :]
print(df_normal.shape)
print(df_abnormal.shape)
# Out:
# (4046, 309)
# (10504, 309)

# %%
# Make both dataset equal
df_normal = df_normal.iloc[:4046, :]
df_abnormal = df_abnormal.iloc[:4046, :]
print(df_normal.shape)
print(df_abnormal.shape)
# Out:
# (4046, 309)
# (4046, 309)

# %%
# Train test split df and df_abnormal
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df_normal, df_abnormal, test_size=0.2, random_state=42)

# %%
# Check NaN value
print(X_train.isnull().sum().sum())
# Out:
# 391556
